# 2017-03-30  14.55  14.64  14.35  14.45      13.68  32928600
# 2017-03-31  14.36  14.65  14.26  14.49      13.72  33553000
# 2017-04-03  14.54  14.75  14.53  14.67      13.89  39427200
# 2017-04-04  14.67  14.89  14.57  14.85      14.06  24132000
# 2017-04-05  15.05  15.16  14.50  14.57      13.80  49920900
# 2017-04-06  14.62  14.87  14.42  14.53      13.76  34602700
# 2017-04-07  14.61  14.90  14.60  14.70      13.92  33024900
# 2017-04-10  14.90  14.94  14.70  14.94      14.15  37906000
# 2017-04-11  14.97  14.99  14.55  14.68      13.90  38593200
# 2017-04-12  14.60  14.83  14.58  14.65      13.87  42628900
# 2017-04-13  14.65  14.69  14.08  14.08      13.33  44572600
# 2017-04-17  14.14  14.35  13.97  14.28      13.52  46459500
# 2017-04-18  14.15  14.37  13.95  14.10      13.35  45349800
# 2017-04-19  14.24  14.28  13.55  13.60      12.88  41014100
# 2017-04-20  13.80  13.90  13.63  13.88      13.14  28227600
# 2017-04-24  14.13  14.16  13.92  14.03      13.28  27546200
# 2017-04-25  13.90  14.34  13.80  14.34      13.58  32268100
# 2017-04-26  14.16  14.49  14.00  14.00      13.26  37045000
# 2017-04-27  13.99  14.03  13.56  13.73      13.00  29078500
# 2017-04-28  13.85  14.10  13.69  13.97      13.23  31061200
#
# [80 rows x 6 columns]

# %%
bovespa = yf.Ticker("^BVSP")
bovespa.info
# Out:
# {'language': 'en-US',
#  'region': 'US',
#  'quoteType': 'INDEX',
#  'quoteSourceName': 'Delayed Quote',
#  'currency': 'BRL',
#  'marketState': 'REGULAR',
#  'exchangeDataDelayedBy': 0,
#  'shortName': 'IBOVESPA',
#  'regularMarketChangePercent': 0.4565334,
#  'regularMarketDayRange': '102245.98 - 102945.45',
#  'regularMarketPreviousClose': 102243.0,
#  'bid': 0.0,
#  'ask': 0.0,
#  'bidSize': 0,
#  'askSize': 0,
#  'messageBoardId': 'finmb_INDEXBVSP',
#  'fullExchangeName': 'Sao Paolo',
#  'averageDailyVolume3Month': 4371395,
#  'averageDailyVolume10Day': 4137650,
#  'fiftyTwoWeekLowChange': 28434.773,
#  'fiftyTwoWeekLowChangePercent': 0.382831,
#  'fiftyTwoWeekRange': '74275.0 - 106650.0',
#  'fiftyTwoWeekHighChange': -3940.2266,
#  'fiftyTwoWeekHighChangePercent': -0.036945395,
#  'fiftyTwoWeekLow': 74275.0,
#  'fiftyTwoWeekHigh': 106650.0,
#  'priceHint': 2,
#  'market': 'br_market',
#  'exchange': 'SAO',
#  'fiftyDayAverage': 99520.914,
#  'fiftyDayAverageChange': 3188.8594,
#  'fiftyDayAverageChangePercent': 0.032042105,
#  'twoHundredDayAverage': 96255.02,
#  'twoHundredDayAverageChange': 6454.75,
#  'twoHundredDayAverageChangePercent': 0.06705884,
#  'sourceInterval': 15,
#  'exchangeTimezoneName': 'America/Sao_Paulo',
#  'exchangeTimezoneShortName': 'BRT',
#  'gmtOffSetMilliseconds': -10800000,
#  'esgPopulated': False,
#  'tradeable': False,
#  'triggerable': False,
#  'regularMarketPrice': 102709.77,
#  'regularMarketTime': 1567778940,
#  'regularMarketChange': 466.77344,
#  'regularMarketOpen': 102246.83,
#  'regularMarketDayHigh': 102945.45,
#  'regularMarketDayLow': 102245.98,
#  'regularMarketVolume': 0,
#  'symbol': '^BVSP'}

# %%
petrobras =yf.Ticker("PETR4.SA")
petrobras.info
# Out:
# {'language': 'en-US',
#  'region': 'US',
#  'quoteType': 'EQUITY',
#  'quoteSourceName': 'Delayed Quote',
#  'currency': 'BRL',
#  'fiftyTwoWeekRange': '18.43 - 29.6',
#  'esgPopulated': False,
#  'tradeable': False,
#  'triggerable': False,
#  'regularMarketPrice': 26.34,
#  'regularMarketTime': 1567778977,
#  'regularMarketChange': -0.049999237,
#  'regularMarketOpen': 26.4,
#  'regularMarketDayHigh': 26.48,
#  'regularMarketDayLow': 26.2,
#  'regularMarketVolume': 7732100,
#  'market': 'br_market',
#  'priceHint': 2,
#  'exchange': 'SAO',
#  'exchangeDataDelayedBy': 0,
#  'marketState': 'REGULAR',
#  'regularMarketChangePercent': -0.18946283,
#  'regularMarketDayRange': '26.2 - 26.48',
#  'regularMarketPreviousClose': 26.39,
#  'bid': 26.34,
#  'ask': 26.35,
#  'bidSize': 0,
#  'askSize': 0,
#  'messageBoardId': 'finmb_409268',
#  'fullExchangeName': 'Sao Paolo',
#  'longName': 'Petróleo Brasileiro S.A. - Petrobras',
#  'fiftyTwoWeekLowChange': 7.91,
#  'financialCurrency': 'BRL',
#  'averageDailyVolume3Month': 44685439,
#  'fiftyTwoWeekHigh': 29.6,
#  'averageDailyVolume10Day': 49982387,
#  'epsTrailingTwelveMonths': 2.426,
#  'epsForward': 3.08,
#  'sharesOutstanding': 5602039808,
#  'fiftyTwoWeekLowChangePercent': 0.42919153,
#  'marketCap': 334923628544,
#  'bookValue': 23.276,
#  'fiftyDayAverage': 25.733612,
#  'fiftyDayAverageChange': 0.6063881,
#  'fiftyDayAverageChangePercent': 0.023564048,
#  'twoHundredDayAverage': 26.849653,
#  'twoHundredDayAverageChange': -0.5096531,
#  'twoHundredDayAverageChangePercent': -0.018981738,
#  'forwardPE': 8.551949,
#  'priceToBook': 1.1316378,
#  'sourceInterval': 15,
#  'exchangeTimezoneName': 'America/Sao_Paulo',
#  'exchangeTimezoneShortName': 'BRT',
#  'gmtOffSetMilliseconds': -10800000,
#  'fiftyTwoWeekHighChange': -3.2600002,
#  'fiftyTwoWeekHighChangePercent': -0.11013514,
#  'fiftyTwoWeekLow': 18.43,
#  'earningsTimestamp': 1541458800,
#  'earningsTimestampStart': 1541458800,
#  'earningsTimestampEnd': 1541458800,
#  'trailingAnnualDividendRate': 1.022,
#  'trailingPE': 10.857378,
#  'trailingAnnualDividendYield': 0.038726788,
#  'shortName': 'PETROBRAS   PN      N2',
#  'symbol': 'PETR4.SA'}
